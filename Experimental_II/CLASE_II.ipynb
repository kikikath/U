# %% [markdown]
# # **HISTOGRAMA**
# ###### https://relopezbriega.github.io/blog/2016/06/29/distribuciones-de-probabilidad-con-python/

# %%
# importando modulos necesarios
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np 
from scipy import stats 
import seaborn as sns 
from numpy import trapz
from scipy.integrate import simps

np.random.seed(2016) # replicar random

# parametros esteticos de seaborn
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8, 4)})

# %%
# Graficando histograma
mu, sigma = 0, 0.2 # media y desvio estandar
datos = np.random.normal(mu, sigma, 500) #creando muestra de datos
# histograma de distribución normal.
frecuencia, limitecolumnas, ignorar = plt.hist(datos, 100) #datos y numero de columnas
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma')
plt.show()

# %% [markdown]
# # **Función de Densidad de Probabilidad**

# %%
x_1 = np.linspace(stats.norm(10, 1.2).ppf(0.01),
                  stats.norm(10, 1.2).ppf(0.99), 100) #datos
FDP_normal = stats.norm(10, 1.2).pdf(x_1) # FDP
plt.plot(x_1, FDP_normal, label='FDP nomal')
plt.title('Función de Densidad de Probabilidad')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()
listSum = sum(FDP_normal)
#print(f"Sum of list -> {listSum}")
area = simps(FDP_normal, x_1)
print("area =", area)
# Out:
# area = 0.980001039423082

# %% [markdown]
# ## **Distribución normal e histograma**

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)
x = np.linspace(norm.ppf(0.01),
                norm.ppf(0.99), 100)
ax.plot(x, norm.pdf(x),
       'r-', lw=5, alpha=0.6, label='norm pdf')
ax.plot(x, norm().pdf(x), 'k-', lw=2, label='frozen pdf')
vals = norm.ppf([0.001, 0.5, 0.999])
np.allclose([0.001, 0.5, 0.999], norm.cdf(vals))
r = norm.rvs(size=1000)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %%
# Graficando histograma
datos = [2,10,4,12,12,13]
# histograma de distribución normal.
frecuencia, limitecolumnas, ignorar = plt.hist(datos, 6) #datos y numero de columnas
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma')
plt.show()
limitecolumnas
# Out:
# array([ 2.        ,  3.83333333,  5.66666667,  7.5       ,  9.33333333,
#        11.16666667, 13.        ])
