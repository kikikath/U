# %% [markdown]
# #### Shirley Maldonado
# 1004807437

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# ##### Campo magnetico de electrodomesticos

# %%
#Celular off
celular_off=pd.read_excel('Celular apagado.xlsx')    #Para leer el archivo sólo debe descargarlo en el pc
cel_off = celular_off['BT'][0:1001]
t_cof = celular_off['time'][0:1001]
N_cof = len(cel_off)
t = np.arange(0,t_cof[1000],1)
print('Promedio Celular off=', np.mean(cel_off))
print('Desviación Celular off=', np.std(cel_off))
print('Error estándar celular off=', np.std(cel_off)/np.sqrt(N_cof), '\n')

#Celular on
celular_on=pd.read_excel('Celular encendido.xlsx')
cel_on = celular_on['BT'][0:1001]
t_con = celular_on['time'][0:1001]
N_con = len(cel_on)
t = np.arange(0,t_con[1000],1)
print('Promedio Celular on=', np.mean(cel_on))
print('Desviación Celular on=', np.std(cel_on))
print('Error estándar celular on=', np.std(cel_on)/np.sqrt(N_con), '\n')

plt.figure(figsize=(12,3))
plt.plot(t_cof, cel_off, lw=1, color='c', ms=6, markerfacecolor='blue', label='Campo magnetico Cel off')
plt.plot(t_con, cel_on, lw=1, color='r', ms=6, markerfacecolor='r', label='Campo magnetico Cel on')

plt.title('Campo magnetico del celular en diferentes estados vs. Tiempo')
plt.ylabel('Campo magentico (µT)',fontsize=12)
plt.xlabel('t(s) \n Figura 1.',fontsize=12)
plt.legend()
plt.show()
# Out:
# Promedio Celular off= 128.90037962037962
# Desviación Celular off= 0.32063133236314234
# Error estándar celular off= 0.010134187167376593
#
# Promedio Celular on= 122.72755244755268
# Desviación Celular on= 0.34271657218123525
# Error estándar celular on= 0.010832234835716945

# %%
#Impresora des
imp_des=pd.read_excel('Impresora desconectada .xlsx')    #Para leer el archivo sólo debe descargarlo en el pc
impr_des = imp_des['BT'][0:800]
t_impd = imp_des['time'][0:800]
N_impd = len(impr_des)
t = np.arange(0,t_impd[799],1)
print('Promedio impresora des=', np.mean(impr_des))
print('Desviación impresora des=', np.std(impr_des))
print('Error estándar impresora des=', np.std(impr_des)/np.sqrt(N_impd), '\n')

#Impresora con
imp_con = pd.read_excel('Impresora conectada .xlsx')
im_con = imp_con['BT'][0:800]
t_imc = imp_con['time'][0:800]
N_imc = len(im_con)
t = np.arange(0,t_imc[799],1)
print('Promedio impresora con=', np.mean(im_con))
print('Desviación impresora con=', np.std(im_con))
print('Error estándar impresora con=', np.std(im_con)/np.sqrt(N_imc), '\n')

#Impresora On
imp_on = pd.read_excel('Impresora funcionando .xlsx')
im_on = imp_on['BT'][0:800]
t_imo = imp_on['time'][0:800]
N_imo = len(im_on)
t = np.arange(0,t_imo[799],1)
print('Promedio impresora on=', np.mean(im_on))
print('Desviación impresora on=', np.std(im_on))
print('Error estándar impresora on=', np.std(im_on)/np.sqrt(N_imo))


plt.figure(figsize=(12,5))
plt.plot(t_impd, impr_des, lw=1, color='c', ms=6, label='Campo magnetico impresora des')
plt.plot(t_imc, im_con, lw=1, color='r', ms=6, label='Campo magnetico impresora con')
plt.plot(t_imo, im_on, lw=1, color='g', ms=6, label='Campo magnetico impresora on')

plt.title('Campo magnetico de una impresora en diferentes estados vs. Tiempo')
plt.ylabel('Campo magentico (µT)',fontsize=12)
plt.xlabel('t(s) \n Figura 2.',fontsize=12)
plt.legend()
plt.show()
# Out:
# Promedio impresora des= 30.991212499999996
# Desviación impresora des= 0.31424418028620654
# Error estándar impresora des= 0.011110209541439231
#
# Promedio impresora con= 30.65234999999997
# Desviación impresora con= 0.29160243054542584
# Error estándar impresora con= 0.010309702802457492
#
# Promedio impresora on= 31.200837500000006
# Desviación impresora on= 0.3538635663553821
# Error estándar impresora on= 0.012510966369237325

# %%
#Microonda des
m_des=pd.read_excel('Microondas desconectado .xlsx')    #Para leer el archivo sólo debe descargarlo en el pc
mi_des = m_des['BT'][0:600]
t_md = m_des['time'][0:600]
N_md = len(mi_des)
t = np.arange(0,t_md[599],1)
print('Promedio microondas des=', np.mean(mi_des))
print('Desviación microondas des=', np.std(mi_des))
print('Error estándar microondas des=', np.std(mi_des)/np.sqrt(N_md), '\n')

#Microondas con
m_con = pd.read_excel('Microondas conectado .xlsx')
mi_con = m_con['BT'][0:600]
t_mc = m_con['time'][0:600]
N_mc = len(mi_con)
t = np.arange(0,t_mc[599],1)
print('Promedio microondas con=', np.mean(mi_con))
print('Desviación microondas con=', np.std(mi_con))
print('Error estándar microondas con=', np.std(mi_con)/np.sqrt(N_mc), '\n')

#Microondas On
m_on = pd.read_excel('Microondas funcionando .xlsx')
mi_on = m_on['BT'][0:600]
t_mo = m_on['time'][0:600]
N_mo = len(mi_on)
t = np.arange(0,t_mo[599],1)
print('Promedio microondas on=', np.mean(mi_on))
print('Desviación microondas on=', np.std(mi_on))
print('Error estándar microondas on=', np.std(mi_on)/np.sqrt(N_mo))

plt.figure(figsize=(15,5))
plt.plot(t_md, mi_des, lw=1, color='c', label='Campo magnetico des')
plt.plot(t_mc, mi_con, lw=1, color='r', label='Campo magnetico con')
plt.plot(t_mo, mi_on, lw=1, color='g', label='Campo magnetico on')

plt.title('Campo magnetico de un microondas en diferentes estados vs. Tiempo')
plt.ylabel('Campo magentico (µT)',fontsize=12)
plt.xlabel('t(s)\n Figura 3.',fontsize=12)
plt.legend()
plt.show()
# Out:
# Promedio microondas des= 91.57018333333329
# Desviación microondas des= 0.24800362844567855
# Error estándar microondas des= 0.010124705734178334
#
# Promedio microondas con= 71.4569666666667
# Desviación microondas con= 0.306387769918376
# Error estándar microondas con= 0.01250822832882124
#
# Promedio microondas on= 87.04221666666665
# Desviación microondas on= 1.343404972345355
# Error estándar microondas on= 0.054844278336064436

# %% [markdown]
# ##### 6. Sonidos

# %%
#Sonido 1
S1=pd.read_excel('Sonido 1.xlsx')   #Tuve que convertilo a formato excel porque con el formato csv sólo mostraba 1 columna.
Ns1=len(S1)
s1 = S1['gain'][0:Ns1] 
print('SONIDO 1')

plt.figure(figsize=(10,5))
n, bins, x = plt.hist(s1, 100, color='gold', alpha=1, edgecolor='black') #Gráfica de histograma
plt.xlabel('Campo magnetico (µT) \n \n Figura 4. Histograma de sonido 1')
plt.ylabel('Frecuencia')

m_s1 = np.mean(s1)
des_s1 = np.std(s1)
er_s1 = des_s1 / np.sqrt(Ns1)
y = norm.pdf( bins, m_s1, des_s1)
plt.plot(bins, y*Ns1*abs(bins[0]-bins[1]), 'r', linewidth=1, label='Curva de ajuste')
plt.legend()
plt.grid()
plt.show()

print('N=', Ns1)
print('Media=',m_s1)
print('Desviación estándar=', des_s1)
print('Error estándar=', er_s1)
er_ers1 = er_s1*(7.1/100)
print('Error en el error:', er_ers1)
print('Valor medio: (41 ± 5) µT')
print('Valor medio con error: (41 ± 0.2) µT\n')


#Sonido 2
S2=pd.read_excel('Sonido 2.xlsx')   
Ns2=len(S2)
s2 = S2['gain'][0:Ns2] 
print('SONIDO 2')

plt.figure(figsize=(10,5))
n, bins, x = plt.hist(s2, 100, color='gold', alpha=1, edgecolor='black') #Gráfica de histograma
plt.xlabel('Campo magnetico (µT) \n \n Figura 5. Histograma de sonido 2')
plt.ylabel('Frecuencia')

m_s2 = np.mean(s2)
des_s2 = np.std(s2)
er_s2 = des_s2 / np.sqrt(Ns2)
y = norm.pdf( bins, m_s2, des_s2)

plt.plot(bins, y*Ns2*abs(bins[0]-bins[1]), 'r', linewidth=1, label='Curva de ajuste')
plt.legend()
plt.grid()
plt.show()

print('N=', Ns2)
print('Media=',m_s2)
print('Desviación estándar=', des_s2)
print('Error estándar=', er_s2)
er_ers2 = er_s2*(7.1/100)
print('Error en el error:', er_ers2)
print('Valor medio: (52 ± 4) µT')
print('Valor medio: (52 ± 0.2) µT\n')

#Sonido 3
S3=pd.read_excel('Sonido 3.xlsx')  
Ns3=len(S3)
s3 = S3['gain'][0:Ns3]
print('SONIDO 3')

plt.figure(figsize=(10,5))
n, bins, x = plt.hist(s3, 100, color='gold', alpha=1, edgecolor='black') #Gráfica de histograma
plt.xlabel('Campo magnetico (µT) \n \n Figura 6. Histograma de sonido 3')
plt.ylabel('Frecuencia')

m_s3 = np.mean(s3)
des_s3 = np.std(s3)
er_s3 = des_s3 / np.sqrt(Ns3)
y = norm.pdf( bins, m_s3, des_s3) 
plt.plot(bins, y*(Ns3)*abs(bins[0]-bins[1]), 'r-', linewidth=1, label='Curva de ajuste')
plt.legend()
plt.grid()
plt.show()

print('N=', Ns3)
print('Media=',m_s3)
print('Desviación estándar=', des_s3)
print('Error estándar=', er_s3)
er_ers3 = er_s3*(7.1/100)
print('Error en el error:', er_ers3)
print('Valor medio: (50 ± 5) ')
print('Valor medio: (50 ± 0.2) µT')
# Out:
# SONIDO 1
# N= 746
# Media= 40.833806970509386
# Desviación estándar= 5.454529341080931
# Error estándar= 0.19970450802729672
# Error en el error: 0.014179020069938066
# Valor medio: (41 ± 5) µT
# Valor medio con error: (41 ± 0.2) µT
#
# SONIDO 2
# N= 625
# Media= 52.026848
# Desviación estándar= 4.332245032877989
# Error estándar= 0.17328980131511953
# Error en el error: 0.012303575893373485
# Valor medio: (52 ± 4) µT
# Valor medio: (52 ± 0.2) µT
#
# SONIDO 3
# N= 620
# Media= 49.97143548387095
# Desviación estándar= 5.377620384882349
# Error estándar= 0.21597043183187992
# Error en el error: 0.015333900660063472
# Valor medio: (50 ± 5)
# Valor medio: (50 ± 0.2) µT

# %%
#Sonido 1
nn = 5
bN = int(np.sqrt(len(s1)/nn))

s11=[]
for ii in range(int(len(s1)/nn)):
  prome = np.sum(s1[int(ii*nn+1):int((ii+1)*nn+1)])/nn
  s11.append(prome)

plt.figure(figsize=(10,5))
n, bins, x = plt.hist(s11, 50, color='gold', edgecolor='black') #Gráfica de histograma
plt.xlabel('Campo magnetico (µT) \n \n Figura 7. Histograma de sonido 1')
plt.ylabel('Frecuencia')
plt.title('(41 ± 4) µT')

m_s11 = np.mean(s11)
des_s11 = np.std(s11)
er_s11 = des_s11 / np.sqrt(len(s11))
y = norm.pdf( bins, m_s11, des_s11)
plt.plot(bins, y*len(s11)*abs(bins[0]-bins[1]), 'r', label='Curva de ajuste')
plt.legend()
plt.grid()
plt.show()


print('SONIDO 1')
print('Tamaño de la muestra = %d'%(int(len(s1)/nn)))
print('Media=',m_s11)
print('Desviación estándar=', des_s11)
print('Error estándar=', er_s11)
er_ers11 = er_s11*(7.1/100)
print('Error en el error:', er_ers11)
print('Valor reportado: 41 +- 4\n')
# Out:
# SONIDO 1
# Tamaño de la muestra = 149
# Media= 40.83167785234899
# Desviación estándar= 3.7378836568025173
# Error estándar= 0.30621936068390604
# Error en el error: 0.021741574608557326
# Valor reportado: 41 +- 4

# %%
#Sonido 2
nn = 5
bN = int(np.sqrt(len(s2)/nn))

s22=[]
for ii in range(int(len(s2)/nn)):
  prome = np.sum(s2[int(ii*nn+1):int((ii+1)*nn+1)])/nn
  s22.append(prome)

plt.figure(figsize=(10,5))
n, bins, x = plt.hist(s22, 50, color='gold', alpha=1, edgecolor='black') #Gráfica de histograma
plt.xlabel('Campo magnetico (µT) \n \n Figura 8. Histograma de sonido 2')
plt.ylabel('Frecuencia')
plt.title('(52 ± 3) µT')

m_s22 = np.mean(s22)
des_s22 = np.std(s22)
er_s22 = des_s22 / np.sqrt(len(s22))
y = norm.pdf( bins, m_s22, des_s22)
plt.plot(bins, y*len(s22)*abs(bins[0]-bins[1]), 'r', linewidth=1, label='Curva de ajuste')
plt.legend()
plt.grid()
plt.show()


print('SONIDO 2')
print('Tamaño de la muestra = %d'%(int(len(s22)/nn)))
print('Media=',m_s22)
print('Desviación estándar=', des_s22)
print('Error estándar=', er_s22)
er_ers22 = er_s22*(7.1/100)
print('Error en el error:', er_ers22)
print('Valor reportado: 52 +- 3')
# Out:
# SONIDO 2
# Tamaño de la muestra = 25
# Media= 51.94350400000001
# Desviación estándar= 2.999046426113473
# Error estándar= 0.26824286705870104
# Error en el error: 0.019045243561167772
# Valor reportado: 52 +- 3

# %%
#Sonido 3
nn = 5
bN = int(np.sqrt(len(s3)/nn))

s33=[]
for ii in range(int(len(s3)/nn)):
  prome = np.sum(s3[int(ii*nn+1):int((ii+1)*nn+1)])/nn
  s33.append(prome)
plt.figure(figsize=(10,5))
n, bins, x = plt.hist(s33, 50, color='gold', alpha=1, edgecolor='black') #Gráfica de histograma
plt.xlabel('Campo magnetico (µT) \n \n Figura 6. Histograma de sonido 3')
plt.ylabel('Frecuencia')
plt.title('(50 ± 3) µT')

m_s33 = np.mean(s33)
des_s33 = np.std(s33)
er_s33 = des_s33 / np.sqrt(len(s33))
y = norm.pdf( bins, m_s33, des_s33)
plt.plot(bins, y*len(s33)*abs(bins[0]-bins[1]), 'r', linewidth=1, label='Curva de ajuste')
plt.legend()
plt.grid()
plt.show()


print('SONIDO 2')
print('Tamaño de la muestra = %d'%(int(len(s33)/nn)))
print('Media=',m_s33)
print('Desviación estándar=', des_s33)
print('Error estándar=', er_s33)
er_ers33 = er_s33*(7.1/100)
print('Error en el error:', er_ers33)
print('Valor reportado: 50 +- 3')
# Out:
# SONIDO 2
# Tamaño de la muestra = 24
# Media= 49.887016129032254
# Desviación estándar= 3.219726190481939
# Error estándar= 0.28913994744251303
# Error en el error: 0.020528936268418424
# Valor reportado: 50 +- 3
